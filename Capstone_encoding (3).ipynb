# %%
import pandas as pd
import tensorflow as tf
# Out:
# time: 14.4 s

# %%
df = pd.read_csv('New_capstone_file.csv')
# Out:
# time: 2.35 s

# %%
df.head()
# Out:
#               race  gender      age  admission_type_id  \
# 0        Caucasian  Female   [0-10)                  6
# 1        Caucasian  Female  [10-20)                  1
# 2  AfricanAmerican  Female  [20-30)                  1
# 3        Caucasian    Male  [30-40)                  1
# 4        Caucasian    Male  [40-50)                  1
#
#    discharge_disposition_id  admission_source_id  time_in_hospital  \
# 0                        25                    1                 1
# 1                         1                    7                 3
# 2                         1                    7                 2
# 3                         1                    7                 2
# 4                         1                    7                 1
#
#    num_medications                                             diag_1  \
# 0                1                           Diabetes mellitus type 1
# 1               18   Other Metabolic Disorders And Immunity Disorders
# 2               13                                Pregnancy Disorders
# 3               16                     Intestinal Infectious Diseases
# 4                8  Malignant Neoplasm Of Other And Unspecified Sites
#
#                                               diag_2  ... glyburide-metformin  \
# 0                                  No Diagnosis Done  ...                  No
# 1                           Diabetes mellitus type 1  ...                  No
# 2                           Diabetes mellitus type 2  ...                  No
# 3                           Diabetes mellitus type 1  ...                  No
# 4  Malignant Neoplasm Of Digestive Organs And Per...  ...                  No
#
#    glipizide-metformin glimepiride-pioglitazone metformin-rosiglitazone  \
# 0                   No                       No                      No
# 1                   No                       No                      No
# 2                   No                       No                      No
# 3                   No                       No                      No
# 4                   No                       No                      No
#
#   metformin-pioglitazone change diabetesMed readmitted num_ovrll_prcdrs  \
# 0                     No     No          No         NO               41
# 1                     No     Ch         Yes        >30               59
# 2                     No     No         Yes         NO               16
# 3                     No     Ch         Yes         NO               45
# 4                     No     Ch         Yes         NO               51
#
#   num_prvs_vists
# 0              0
# 1              0
# 2              3
# 3              0
# 4              0
#
# [5 rows x 42 columns]
# time: 173 ms

# %%
df.skew()
# Out:
# admission_type_id           1.591984
# discharge_disposition_id    2.563067
# admission_source_id         1.029935
# time_in_hospital            1.133999
# num_medications             1.326672
# number_diagnoses           -0.876746
# num_ovrll_prcdrs           -0.210995
# num_prvs_vists              5.315210
# dtype: float64
# time: 1.3 s

# %%
sk_l = ['time_in_hospital',
'num_medications','number_diagnoses','num_ovrll_prcdrs','num_prvs_vists']
# Out:
# time: 1.96 ms

# %%
from scipy.stats import boxcox
# Out:
# time: 1.53 s

# %%
for i in sk_l:
    df[i] = list(boxcox(df[i]+1)[0])
# Out:
# time: 2.18 s

# %%
df.skew()
# Out:
# admission_type_id           1.591984
# discharge_disposition_id    2.563067
# admission_source_id         1.029935
# time_in_hospital            0.012906
# num_medications             0.018905
# number_diagnoses           -0.137440
# num_ovrll_prcdrs           -0.190099
# num_prvs_vists              0.413960
# dtype: float64
# time: 1.66 s

# %%
# Out:
# time: 178 ms

# %%
import statsmodels.api
# Out:
# time: 2.63 s

# %%
import seaborn as sns
import matplotlib.pyplot as plt
def boxplot_outliers_plot(df, columns=[]):
    """
       We Plot the outliers of non categorical columns in the data set
       Parameters :
       df : DataFrame
       columns : If we want only specific columns , we can use this list
       Returns :
       Boxplot of the columns
    """
    # Importing the Libraries required

    # Taking the columns in the data frame If columns list is empty
    if len(columns) == 0:
        columns = df.columns
    # Taking columns in columns list if columns list is not empty
    elif len(columns) != 0:
        columns = columns
    # Correct backend code
    else:
        raise ValueError('Something wrong in backend code here')
    # Taking column from columns list
    for column in columns:
        # The column should be present in DataFrame
        if column in df.columns:
            # We can only calculate outliers for non-categorical columns
            if df[column].dtype != 'O':
                print(column)
                sns.boxplot(df[column])
                plt.show()
            else:
                print('Cannot find Outliers for ', column,
                      'as it is a categorical column')
                print('\n')
        # Column should be in DataFrame
        elif column not in df.columns:
            raise ValueError('The column is not in the DataFrame')
        # Correct backend code
        else:
            raise ValueError('Something wrong in backend code here')
# Out:
# time: 1.45 s

# %%
boxplot_outliers_plot(df)
# Out:
# Cannot find Outliers for  race as it is a categorical column
#
#
# Cannot find Outliers for  gender as it is a categorical column
#
#
# Cannot find Outliers for  age as it is a categorical column
#
#
# admission_type_id
# discharge_disposition_id
# admission_source_id
# time_in_hospital
# num_medications
# Cannot find Outliers for  diag_1 as it is a categorical column
#
#
# Cannot find Outliers for  diag_2 as it is a categorical column
#
#
# Cannot find Outliers for  diag_3 as it is a categorical column
#
#
# number_diagnoses
# Cannot find Outliers for  max_glu_serum as it is a categorical column
#
#
# Cannot find Outliers for  A1Cresult as it is a categorical column
#
#
# Cannot find Outliers for  metformin as it is a categorical column
#
#
# Cannot find Outliers for  repaglinide as it is a categorical column
#
#
# Cannot find Outliers for  nateglinide as it is a categorical column
#
#
# Cannot find Outliers for  chlorpropamide as it is a categorical column
#
#
# Cannot find Outliers for  glimepiride as it is a categorical column
#
#
# Cannot find Outliers for  acetohexamide as it is a categorical column
#
#
# Cannot find Outliers for  glipizide as it is a categorical column
#
#
# Cannot find Outliers for  glyburide as it is a categorical column
#
#
# Cannot find Outliers for  tolbutamide as it is a categorical column
#
#
# Cannot find Outliers for  pioglitazone as it is a categorical column
#
#
# Cannot find Outliers for  rosiglitazone as it is a categorical column
#
#
# Cannot find Outliers for  acarbose as it is a categorical column
#
#
# Cannot find Outliers for  miglitol as it is a categorical column
#
#
# Cannot find Outliers for  troglitazone as it is a categorical column
#
#
# Cannot find Outliers for  tolazamide as it is a categorical column
#
#
# Cannot find Outliers for  examide as it is a categorical column
#
#
# Cannot find Outliers for  citoglipton as it is a categorical column
#
#
# Cannot find Outliers for  insulin as it is a categorical column
#
#
# Cannot find Outliers for  glyburide-metformin as it is a categorical column
#
#
# Cannot find Outliers for  glipizide-metformin as it is a categorical column
#
#
# Cannot find Outliers for  glimepiride-pioglitazone as it is a categorical column
#
#
# Cannot find Outliers for  metformin-rosiglitazone as it is a categorical column
#
#
# Cannot find Outliers for  metformin-pioglitazone as it is a categorical column
#
#
# Cannot find Outliers for  change as it is a categorical column
#
#
# Cannot find Outliers for  diabetesMed as it is a categorical column
#
#
# Cannot find Outliers for  readmitted as it is a categorical column
#
#
# num_ovrll_prcdrs
# num_prvs_vists
# time: 19 s

# %%
sk_l
# Out:
# ['time_in_hospital',
#  'num_medications',
#  'number_diagnoses',
#  'num_ovrll_prcdrs',
#  'num_prvs_vists']
# time: 14 ms

# %%
s_df = df[sk_l]
s_df
# Out:
#         time_in_hospital  num_medications  number_diagnoses  num_ovrll_prcdrs  \
# 0               0.671436         0.762794          1.817283         42.757811
# 1               1.301253         4.512864        113.322272         61.835981
# 2               1.044738         3.860123         47.157593         16.484523
# 3               1.044738         4.268823         65.513476         46.988444
# 4               0.671436         3.006707         32.226094         53.344494
# ...                  ...              ...               ...               ...
# 101761          1.301253         4.268823        113.322272         53.344494
# 101762          1.651416         4.512864        113.322272         37.477991
# 101763          0.671436         3.201002        258.420595         55.465659
# 101764          2.151036         4.846015        113.322272         49.105837
# 101765          1.781141         1.683847        113.322272         16.484523
#
#         num_prvs_vists
# 0             0.000000
# 1             0.000000
# 2             0.718183
# 3             0.000000
# 4             0.000000
# ...                ...
# 101761        0.000000
# 101762        0.487716
# 101763        0.487716
# 101764        0.487716
# 101765        0.000000
#
# [101766 rows x 5 columns]
# time: 72 ms

# %%
from sklearn.preprocessing import StandardScaler
# Out:
# time: 189 ms

# %%
ss = StandardScaler()
# Out:
# time: 3 ms

# %%
s_s_df = ss.fit_transform(s_df)
# Out:
# time: 43 ms

# %%
s_s_df = pd.DataFrame(s_s_df,columns=sk_l)
# Out:
# time: 3 ms

# %%
s_s_df
# Out:
#         time_in_hospital  num_medications  number_diagnoses  num_ovrll_prcdrs  \
# 0              -1.632460        -3.304858         -2.125874         -0.177270
# 1              -0.271144         0.408817          0.865090          0.733542
# 2              -0.825587        -0.237590         -0.909684         -1.431584
# 3              -0.825587         0.167145         -0.417314          0.024705
# 4              -1.632460        -1.082723         -1.310201          0.328150
# ...                  ...              ...               ...               ...
# 101761         -0.271144         0.167145          0.865090          0.328150
# 101762          0.485715         0.408817          0.865090         -0.429334
# 101763         -1.632460        -0.890313          4.757148          0.429416
# 101764          1.565616         0.738735          0.865090          0.125792
# 101765          0.766108        -2.392744          0.865090         -1.431584
#
#         num_prvs_vists
# 0            -0.873587
# 1            -0.873587
# 2             1.368394
# 3            -0.873587
# 4            -0.873587
# ...                ...
# 101761       -0.873587
# 101762        0.648937
# 101763        0.648937
# 101764        0.648937
# 101765       -0.873587
#
# [101766 rows x 5 columns]
# time: 43 ms

# %%
df.drop(sk_l,axis=1,inplace=True)
# Out:
# time: 94.1 ms

# %%
df = pd.concat([df,s_s_df],axis=1)
# Out:
# time: 114 ms

# %%
df[df['gender']=='Unknown/Invalid'].index.tolist()
# Out:
# [30506, 75551, 82573]
# time: 104 ms

# %%
df.drop(df[df['gender']=='Unknown/Invalid'].index.tolist(),axis=0,inplace=True)
# Out:
# time: 152 ms

# %%
df.gender = df.gender.map({'Female':0,'Male':1})
# Out:
# time: 69 ms

# %%
df.change = df.change.map({'No':0,'Ch':1})
# Out:
# time: 50 ms

# %%
df.diabetesMed = df.diabetesMed.map({'Yes':0,'No':1})
# Out:
# time: 91.5 ms

# %%
df.diabetesMed.value_counts()
# Out:
# 0    78361
# 1    23402
# Name: diabetesMed, dtype: int64
# time: 17 ms

# %%
l_d = ['acarbose','acetohexamide','chlorpropamide','citoglipton','examide','glimepiride-pioglitazone','glipizide-metformin','glyburide-metformin','metformin-pioglitazone','metformin-rosiglitazone','miglitol','tolazamide','troglitazone','tolbutamide','nateglinide','glyburide']
# Out:
# time: 3 ms

# %%
df.drop(l_d,inplace=True,axis=1)
# Out:
# time: 65 ms

# %%
X = df.drop('readmitted',axis=1)
y = df['readmitted']
# Out:
# time: 36 ms

# %%
X.skew()
# Out:
# gender                      0.150838
# admission_type_id           1.591977
# discharge_disposition_id    2.563169
# admission_source_id         1.029942
# change                      0.152661
# diabetesMed                 1.283420
# time_in_hospital            0.012915
# num_medications             0.018932
# number_diagnoses           -0.137451
# num_ovrll_prcdrs           -0.190096
# num_prvs_vists              0.413910
# dtype: float64
# time: 716 ms

# %%
y.value_counts()
# Out:
# NO     54861
# >30    35545
# <30    11357
# Name: readmitted, dtype: int64
# time: 44 ms

# %%
y = y.map({'NO':0,'>30':1,'<30':2})
# Out:
# time: 25 ms

# %% [markdown]
# cat_cols = ['diag_1', 'diag_2', 'diag_3']

# %%
cat_cols = X.describe(include='O').columns.tolist()
# Out:
# time: 611 ms

# %%
from sklearn.base import BaseEstimator
class MeanEncoding(BaseEstimator):

    """   In Mean Encoding we take the number
    of labels into account along with the target variable
    to encode the labels into machine comprehensible values    """

    def __init__(self, feature, C=0.1):
        self.C = C
        self.feature = feature

    def fit(self, X_train, y_train):

        df = pd.DataFrame(
            {'feature': X_train[self.feature], 'target': y_train}).dropna()

        self.global_mean = df.target.mean()
        mean = df.groupby('feature').target.mean()
        size = df.groupby('feature').target.size()

        self.encoding = (self.global_mean * self.C +
                         mean * size) / (self.C + size)

    def transform(self, X_test):

        X_test[self.feature] = X_test[self.feature].map(
            self.encoding).fillna(self.global_mean).values

        return X_test

    def fit_transform(self, X_train, y_train):

        df = pd.DataFrame(
            {'feature': X_train[self.feature], 'target': y_train}).dropna()

        self.global_mean = df.target.mean()
        mean = df.groupby('feature').target.mean()
        size = df.groupby('feature').target.size()
        self.encoding = (self.global_mean * self.C +
                         mean * size) / (self.C + size)

        X_train[self.feature] = X_train[self.feature].map(
            self.encoding).fillna(self.global_mean).values

        return X_train

for f in cat_cols + ['admission_type_id','discharge_disposition_id','admission_source_id']:
    me = MeanEncoding(f, C=0.01 * len(X[f].unique()))
    me.fit(X, y)
    X = me.transform(X)
# Out:
# time: 1.89 s

# %%
X
# Out:
#             race  gender       age  admission_type_id  \
# 0       0.577032       0  0.198990           0.643167
# 1       0.577032       0  0.439961           0.588112
# 2       0.569703       0  0.592636           0.588112
# 3       0.577032       1  0.539074           0.588112
# 4       0.577032       1  0.550542           0.588112
# ...          ...     ...       ...                ...
# 101761  0.569703       1  0.598979           0.588112
# 101762  0.569703       0  0.603535           0.588112
# 101763  0.577032       1  0.598979           0.588112
# 101764  0.577032       0  0.603535           0.572727
# 101765  0.577032       1  0.598979           0.588112
#
#         discharge_disposition_id  admission_source_id    diag_1    diag_2  \
# 0                       0.566230             0.537816  0.616704  0.369356
# 1                       0.543250             0.610641  0.579307  0.662444
# 2                       0.543250             0.610641  0.399032  0.510324
# 3                       0.543250             0.610641  0.639189  0.662444
# 4                       0.543250             0.610641  0.455922  0.664514
# ...                          ...                  ...       ...       ...
# 101761                  0.645548             0.610641  0.616704  0.514493
# 101762                  0.596311             0.512293  0.569647  0.572521
# 101763                  0.543250             0.610641  0.551177  0.573503
# 101764                  0.645548             0.610641  0.617650  0.543757
# 101765                  0.543250             0.610641  0.563662  0.634672
#
#           diag_3  max_glu_serum  ...  pioglitazone  rosiglitazone   insulin  \
# 0       0.365589       0.570449  ...      0.571329       0.571494  0.537379
# 1       0.609798       0.570449  ...      0.571329       0.571494  0.645281
# 2       0.561094       0.570449  ...      0.571329       0.571494  0.537379
# 3       0.527934       0.570449  ...      0.571329       0.571494  0.645281
# 4       0.536956       0.570449  ...      0.571329       0.571494  0.562352
# ...          ...            ...  ...           ...            ...       ...
# 101761  0.610114       0.570449  ...      0.571329       0.571494  0.666885
# 101762  0.588002       0.570449  ...      0.571329       0.571494  0.562352
# 101763  0.629516       0.570449  ...      0.571329       0.571494  0.666885
# 101764  0.574373       0.570449  ...      0.584086       0.571494  0.645281
# 101765  0.588002       0.570449  ...      0.571329       0.571494  0.537379
#
#         change  diabetesMed  time_in_hospital  num_medications  \
# 0            0            1         -1.632460        -3.304858
# 1            1            0         -0.271144         0.408817
# 2            0            0         -0.825587        -0.237590
# 3            1            0         -0.825587         0.167145
# 4            1            0         -1.632460        -1.082723
# ...        ...          ...               ...              ...
# 101761       1            0         -0.271144         0.167145
# 101762       0            0          0.485715         0.408817
# 101763       1            0         -1.632460        -0.890313
# 101764       1            0          1.565616         0.738735
# 101765       0            1          0.766108        -2.392744
#
#         number_diagnoses  num_ovrll_prcdrs  num_prvs_vists
# 0              -2.125874         -0.177270       -0.873587
# 1               0.865090          0.733542       -0.873587
# 2              -0.909684         -1.431584        1.368394
# 3              -0.417314          0.024705       -0.873587
# 4              -1.310201          0.328150       -0.873587
# ...                  ...               ...             ...
# 101761          0.865090          0.328150       -0.873587
# 101762          0.865090         -0.429334        0.648937
# 101763          4.757148          0.429416        0.648937
# 101764          0.865090          0.125792        0.648937
# 101765          0.865090         -1.431584       -0.873587
#
# [101763 rows x 25 columns]
# time: 317 ms

# %%
X.describe()
# Out:
#                 race         gender            age  admission_type_id  \
# count  101763.000000  101763.000000  101763.000000      101763.000000
# mean        0.572497       0.462398       0.572497           0.572498
# std         0.016037       0.498587       0.033208           0.034540
# min         0.453987       0.000000       0.198990           0.002173
# 25%         0.577032       0.000000       0.550542           0.572727
# 50%         0.577032       0.000000       0.573837           0.588112
# 75%         0.577032       1.000000       0.598979           0.588112
# max         0.577032       1.000000       0.603535           0.643167
#
#        discharge_disposition_id  admission_source_id         diag_1  \
# count             101763.000000        101763.000000  101763.000000
# mean                   0.572497             0.572502       0.572537
# std                    0.105336             0.057563       0.081163
# min                    0.000091             0.044850       0.104771
# 25%                    0.543250             0.537816       0.533086
# 50%                    0.543250             0.610641       0.569647
# 75%                    0.645548             0.610641       0.646054
# max                    1.272653             0.776182       1.611941
#
#               diag_2         diag_3  max_glu_serum  ...   pioglitazone  \
# count  101763.000000  101763.000000  101763.000000  ...  101763.000000
# mean        0.572585       0.572565       0.572497  ...       0.572497
# std         0.065258       0.066623       0.014777  ...       0.006026
# min         0.063862       0.079572       0.567963  ...       0.571329
# 25%         0.529538       0.529162       0.570449  ...       0.571329
# 50%         0.570705       0.557471       0.570449  ...       0.571329
# 75%         0.620048       0.629516       0.570449  ...       0.571329
# max         0.883032       0.932247       0.698572  ...       0.686402
#
#        rosiglitazone        insulin         change    diabetesMed  \
# count  101763.000000  101763.000000  101763.000000  101763.000000
# mean        0.572497       0.572497       0.461946       0.229966
# std         0.008358       0.047583       0.498552       0.420813
# min         0.367910       0.537379       0.000000       0.000000
# 25%         0.571494       0.537379       0.000000       0.000000
# 50%         0.571494       0.562352       0.000000       0.000000
# 75%         0.571494       0.562352       1.000000       0.000000
# max         0.593048       0.666885       1.000000       1.000000
#
#        time_in_hospital  num_medications  number_diagnoses  num_ovrll_prcdrs  \
# count     101763.000000     1.017630e+05     101763.000000     101763.000000
# mean           0.000020    -5.907783e-07          0.000020          0.000012
# std            0.999986     1.000002e+00          0.999995          1.000001
# min           -1.632460    -3.304858e+00         -2.125874         -2.170557
# 25%           -0.825587    -7.114438e-01         -0.909684         -0.580334
# 50%            0.148889     3.846507e-02          0.172531          0.024705
# 75%            0.766108     6.326173e-01          0.865090          0.682822
# max            2.095259     4.370038e+00          8.972998          4.615393
#
#        num_prvs_vists
# count   101763.000000
# mean         0.000026
# std          1.000008
# min         -0.873587
# 25%         -0.873587
# 50%         -0.873587
# 75%          1.133159
# max          1.988036
#
# [8 rows x 25 columns]
# time: 454 ms

# %%
X
# Out:
#             race  gender       age  admission_type_id  \
# 0       0.577032       0  0.198990           0.643167
# 1       0.577032       0  0.439961           0.588112
# 2       0.569703       0  0.592636           0.588112
# 3       0.577032       1  0.539074           0.588112
# 4       0.577032       1  0.550542           0.588112
# ...          ...     ...       ...                ...
# 101761  0.569703       1  0.598979           0.588112
# 101762  0.569703       0  0.603535           0.588112
# 101763  0.577032       1  0.598979           0.588112
# 101764  0.577032       0  0.603535           0.572727
# 101765  0.577032       1  0.598979           0.588112
#
#         discharge_disposition_id  admission_source_id    diag_1    diag_2  \
# 0                       0.566230             0.537816  0.616704  0.369356
# 1                       0.543250             0.610641  0.579307  0.662444
# 2                       0.543250             0.610641  0.399032  0.510324
# 3                       0.543250             0.610641  0.639189  0.662444
# 4                       0.543250             0.610641  0.455922  0.664514
# ...                          ...                  ...       ...       ...
# 101761                  0.645548             0.610641  0.616704  0.514493
# 101762                  0.596311             0.512293  0.569647  0.572521
# 101763                  0.543250             0.610641  0.551177  0.573503
# 101764                  0.645548             0.610641  0.617650  0.543757
# 101765                  0.543250             0.610641  0.563662  0.634672
#
#           diag_3  max_glu_serum  ...  pioglitazone  rosiglitazone   insulin  \
# 0       0.365589       0.570449  ...      0.571329       0.571494  0.537379
# 1       0.609798       0.570449  ...      0.571329       0.571494  0.645281
# 2       0.561094       0.570449  ...      0.571329       0.571494  0.537379
# 3       0.527934       0.570449  ...      0.571329       0.571494  0.645281
# 4       0.536956       0.570449  ...      0.571329       0.571494  0.562352
# ...          ...            ...  ...           ...            ...       ...
# 101761  0.610114       0.570449  ...      0.571329       0.571494  0.666885
# 101762  0.588002       0.570449  ...      0.571329       0.571494  0.562352
# 101763  0.629516       0.570449  ...      0.571329       0.571494  0.666885
# 101764  0.574373       0.570449  ...      0.584086       0.571494  0.645281
# 101765  0.588002       0.570449  ...      0.571329       0.571494  0.537379
#
#         change  diabetesMed  time_in_hospital  num_medications  \
# 0            0            1         -1.632460        -3.304858
# 1            1            0         -0.271144         0.408817
# 2            0            0         -0.825587        -0.237590
# 3            1            0         -0.825587         0.167145
# 4            1            0         -1.632460        -1.082723
# ...        ...          ...               ...              ...
# 101761       1            0         -0.271144         0.167145
# 101762       0            0          0.485715         0.408817
# 101763       1            0         -1.632460        -0.890313
# 101764       1            0          1.565616         0.738735
# 101765       0            1          0.766108        -2.392744
#
#         number_diagnoses  num_ovrll_prcdrs  num_prvs_vists
# 0              -2.125874         -0.177270       -0.873587
# 1               0.865090          0.733542       -0.873587
# 2              -0.909684         -1.431584        1.368394
# 3              -0.417314          0.024705       -0.873587
# 4              -1.310201          0.328150       -0.873587
# ...                  ...               ...             ...
# 101761          0.865090          0.328150       -0.873587
# 101762          0.865090         -0.429334        0.648937
# 101763          4.757148          0.429416        0.648937
# 101764          0.865090          0.125792        0.648937
# 101765          0.865090         -1.431584       -0.873587
#
# [101763 rows x 25 columns]
# time: 163 ms

# %%
X.shape
# Out:
# (101763, 25)
# time: 6 ms

# %%
X_constant = statsmodels.api.add_constant(X)
# Out:
# time: 113 ms

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = [variance_inflation_factor(X_constant.values, i) for i in range(X_constant.shape[1])]
# Out:
# time: 10.9 s

# %%
pd.DataFrame({'vif': vif[1:]}, index=X.columns)
# Out:
#                                vif
# race                      1.010335
# gender                    1.010259
# age                       1.056808
# admission_type_id         1.245098
# discharge_disposition_id  1.035619
# admission_source_id       1.185516
# diag_1                    1.143242
# diag_2                    1.122508
# diag_3                    1.156779
# max_glu_serum             1.028512
# A1Cresult                 1.079642
# metformin                 1.336669
# repaglinide               1.015129
# glimepiride               1.000904
# glipizide                 1.132260
# pioglitazone              1.050564
# rosiglitazone             1.017966
# insulin                   2.188676
# change                    2.501751
# diabetesMed               1.468668
# time_in_hospital          1.438442
# num_medications           1.567363
# number_diagnoses          1.272883
# num_ovrll_prcdrs          1.342806
# num_prvs_vists            1.075474
# time: 30 ms

# %%
len(X.columns)
# Out:
# 25
# time: 7 ms

# %%
import imblearn
# Out:
# time: 1.57 s

# %%
smote = imblearn.over_sampling.SMOTE(random_state=96)
# Out:
# time: 15 ms

# %%
X_rs,y_rs = smote.fit_resample(X,y)
# Out:
# time: 49.8 s

# %%
X_rs.shape
# Out:
# (164583, 25)
# time: 8.99 ms

# %%
y_rs.value_counts()
# Out:
# 2    54861
# 1    54861
# 0    54861
# Name: readmitted, dtype: int64
# time: 31 ms

# %%
df_new = pd.concat([X_rs,y_rs],axis=1)
# Out:
# time: 64 ms

# %%
df_new
# Out:
#             race  gender       age  admission_type_id  \
# 0       0.577032       0  0.198990           0.643167
# 1       0.577032       0  0.439961           0.588112
# 2       0.569703       0  0.592636           0.588112
# 3       0.577032       1  0.539074           0.588112
# 4       0.577032       1  0.550542           0.588112
# ...          ...     ...       ...                ...
# 164578  0.577032       0  0.548315           0.573521
# 164579  0.577032       0  0.550542           0.572727
# 164580  0.577032       1  0.599916           0.588112
# 164581  0.577032       1  0.570683           0.572727
# 164582  0.577032       0  0.574828           0.588112
#
#         discharge_disposition_id  admission_source_id    diag_1    diag_2  \
# 0                       0.566230             0.537816  0.616704  0.369356
# 1                       0.543250             0.610641  0.579307  0.662444
# 2                       0.543250             0.610641  0.399032  0.510324
# 3                       0.543250             0.610641  0.639189  0.662444
# 4                       0.543250             0.610641  0.455922  0.664514
# ...                          ...                  ...       ...       ...
# 164578                  0.562965             0.596606  0.666331  0.565511
# 164579                  0.543250             0.543797  0.463905  0.621894
# 164580                  0.624512             0.610641  0.559822  0.591012
# 164581                  0.157453             0.537816  0.594899  0.603862
# 164582                  0.669507             0.610641  0.569288  0.563326
#
#           diag_3  max_glu_serum  ...  rosiglitazone   insulin  change  \
# 0       0.365589       0.570449  ...       0.571494  0.537379       0
# 1       0.609798       0.570449  ...       0.571494  0.645281       1
# 2       0.561094       0.570449  ...       0.571494  0.537379       0
# 3       0.527934       0.570449  ...       0.571494  0.645281       1
# 4       0.536956       0.570449  ...       0.571494  0.562352       1
# ...          ...            ...  ...            ...       ...     ...
# 164578  0.510149       0.570449  ...       0.571494  0.562352       1
# 164579  0.530579       0.569997  ...       0.571494  0.562352       0
# 164580  0.575650       0.570449  ...       0.571494  0.564010       1
# 164581  0.529345       0.570449  ...       0.571494  0.562352       0
# 164582  0.619788       0.570449  ...       0.571494  0.614473       1
#
#         diabetesMed  time_in_hospital  num_medications  number_diagnoses  \
# 0                 1         -1.632460        -3.304858         -2.125874
# 1                 0         -0.271144         0.408817          0.865090
# 2                 0         -0.825587        -0.237590         -0.909684
# 3                 0         -0.825587         0.167145         -0.417314
# 4                 0         -1.632460        -1.082723         -1.310201
# ...             ...               ...              ...               ...
# 164578            0          0.766108         1.497467          0.865090
# 164579            0         -0.825587        -0.333749         -1.310201
# 164580            0          0.766108        -0.096210          0.865090
# 164581            0          2.086319        -0.383017         -0.926532
# 164582            0          0.886282         0.790208          0.865090
#
#         num_ovrll_prcdrs  num_prvs_vists  readmitted
# 0              -0.177270       -0.873587           0
# 1               0.733542       -0.873587           1
# 2              -1.431584        1.368394           0
# 3               0.024705       -0.873587           0
# 4               0.328150       -0.873587           0
# ...                  ...             ...         ...
# 164578          0.989198        1.133159           2
# 164579         -0.899949       -0.873587           2
# 164580          0.359390       -0.873587           2
# 164581          0.118653        1.497799           2
# 164582          1.343108       -0.873587           2
#
# [164583 rows x 26 columns]
# time: 240 ms

# %%
df_new.to_csv('Capstone_oversampled.csv',index=False)
# Out:
# time: 57.1 s
